# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelncsu/Bacterial-WGS-bioinformatics-workshop/blob/main/Day_2/Bioinformatics_course_Day_2_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Bacterial WGS bioinformatics workshop**
# ## **Day 2 - Part 1.** Downloading and processing WGS using Bactopia pipeline

# %% [markdown]
# ##**Step 1:** Mounting your google drive into google colab

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ##Lets go to the workshop main folder

# %%
cd /content/gdrive/Shareddrives/Bacterial_bioinformatics_workshop/Day_2
# Out:
# /content/gdrive/Shareddrives/Bacterial_bioinformatics_workshop/Day_2

# %% [markdown]
# ##Install Conda

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %% [markdown]
# ## Lets create a virtual environment

# %%
# !python --version
# Out:
# Python 3.10.10

# %%
# install virtual environment package
# !pip install virtualenv

# %%
# create virtual environment
# !virtualenv bactopia

# %%
# Lets check our new virtual environment
# !ls
# Out:
# bin  lib  pyvenv.cfg

# %%
#Activate the environment
# !source bactopia/bin/activate

# %%
cd bactopia
# Out:
# /content/bactopia

# %% [markdown]
# ## Install Mamba inside our virtual environment

# %%
# Install Mamba
# !conda install -c conda-forge mamba -y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Link to the article: https://journals.asm.org/doi/full/10.1128/msystems.00190-20

# %% [markdown]
# ## Lets install Bactopia

# %%
ls
# Out:
# bin/  lib/  pyvenv.cfg  SRA_sequences_subsample.txt

# %%
# !mamba install -c rpetit3 -c conda-forge -c bioconda bactopia

# %%
# !which bactopia
# Out:
# /usr/local/bin/bactopia

# %% [markdown]
# ## Search metadata using Bactopia

# %% [markdown]
# ### You will have to manually upload the SRA_sequences_subsample.txt file into your bactopia folder using the upload button

# %% [markdown]
# ### Start by uploading the list of sequences we generated yesterday

# %%
# !bactopia search --query SRA_sequences_subsample.txt
# Out:
# 2024-02-02 02:06:55 INFO     2024-02-02 02:06:55:root:INFO - Submitting query (type -  ]8;id=230032;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py\search.py]8;;\:]8;id=263076;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py#472\472]8;;\
#                              run_accession)
# 2024-02-02 02:06:56 INFO     2024-02-02 02:06:56:root:INFO - Writing results to        ]8;id=968728;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py\search.py]8;;\:]8;id=562480;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py#554\554]8;;\
#                              ./bactopia-metadata.txt
#                     INFO     2024-02-02 02:06:56:root:INFO - Writing accessions to     ]8;id=673843;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py\search.py]8;;\:]8;id=702465;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py#564\564]8;;\
#                              ./bactopia-accessions.txt
#                     INFO     2024-02-02 02:06:56:root:INFO - Writing filtered          ]8;id=927473;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py\search.py]8;;\:]8;id=545489;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py#570\570]8;;\
#                              accessions to ./bactopia-filtered.txt
#                     INFO     2024-02-02 02:06:56:root:INFO - Writing summary to        ]8;id=214507;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py\search.py]8;;\:]8;id=13476;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/search.py#576\576]8;;\
#                              ./bactopia-search.txt

# %% [markdown]
# # Lets check each of the generated files

# %% [markdown]
# ## Metadata file

# %%
import pandas as pd

# Add the path to your file
file_path = 'bactopia-metadata.txt'

# Read the entire file into a Pandas DataFrame
df = pd.read_csv(file_path, sep='\t')

# Load the data_table extension for interactive display
# %load_ext google.colab.data_table

# Display the DataFrame
df
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
# Warning: Total number of columns (50) exceeds max_columns (20). Falling back to pandas display.
#   run_accession                                   experiment_title  \
# 0    SRR4300580  Illumina MiSeq sequencing: WGS of Clostridium ...
# 1    SRR4300579  Illumina MiSeq sequencing: WGS of Clostridium ...
#
#   sample_accession submission_accession library_selection last_updated  \
# 0     SAMN05832947            SRA480763            RANDOM   2016-10-05
# 1     SAMN05832946            SRA480763            RANDOM   2016-10-05
#
#    sra_bytes          fastq_bytes instrument_platform  \
# 0  316789107  165442495;214863880            ILLUMINA
# 1  695413420  384579817;460952601            ILLUMINA
#
#                                           sra_aspera  ... strain  \
# 0  fasp.sra.ebi.ac.uk:/vol1/srr/SRR430/000/SRR430...  ...  127A5
# 1  fasp.sra.ebi.ac.uk:/vol1/srr/SRR430/009/SRR430...  ...  127A2
#
#   experiment_accession           scientific_name tax_id study_accession  \
# 0           SRX2195088  Clostridioides difficile   1496     PRJNA344770
# 1           SRX2195087  Clostridioides difficile   1496     PRJNA344770
#
#     accession secondary_sample_accession  first_public  study_alias  \
# 0  SRR4300580                 SRS1717253    2016-10-05  PRJNA344770
# 1  SRR4300579                 SRS1717252    2016-10-05  PRJNA344770
#
#   isolation_source
# 0            stool
# 1            stool
#
# [2 rows x 50 columns]

# %% [markdown]
# ## Bactopia accessions file - This file will be used for further analysis

# %%
import pandas as pd

# Add the path to your file
file_path = 'bactopia-accessions.txt'

# Read the entire file into a Pandas DataFrame
df = pd.read_csv(file_path, sep='\t')

# Load the data_table extension for interactive display
# %load_ext google.colab.data_table

# Display the DataFrame
df
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
#     accession   runtype                   species  genome_size
# 0  SRX2195087  illumina  Clostridioides difficile      3605000
# 1  SRX2195088  illumina  Clostridioides difficile      3605000

# %% [markdown]
# ### Before running Bactopia it would be good to check the number of CPU cores available in your Colab environment

# %%
import multiprocessing
print(multiprocessing.cpu_count())
# Out:
# 2

# %% [markdown]
# ## Lets run Bactopia pipeline

# %%
# !bactopia --accessions bactopia-accessions.txt --outdir ./Bactopia_results/ --cleanup_workdir --cpus 2
# Out:
# 2024-02-02 02:07:58 INFO     2024-02-02 02:07:58:root:INFO - Checking if environment ]8;id=415376;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/download.py\download.py]8;;\:]8;id=605780;file:///usr/local/lib/python3.10/site-packages/bactopia/cli/download.py#544\544]8;;\
#                              pre-builds are needed (this may take a while if
#                              building for the first time)
# N E X T F L O W  ~  version 23.10.1
# Launching `/usr/local/share/bactopia-3.0.1/main.nf` [ridiculous_meninsky] DSL2 - revision: 0cd9f79ba7
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
#
# WARN: Found unexpected parameters:
# * --cpus: 8
# - Ignore this warning: params.schema_ignore_params = "cpus"
#
#
#
# ---------------------------------------------
#    _                _              _
#   | |__   __ _  ___| |_ ___  _ __ (_) __ _
#   | '_ \ / _` |/ __| __/ _ \| '_ \| |/ _` |
#   | |_) | (_| | (__| || (_) | |_) | | (_| |
#   |_.__/ \__,_|\___|\__\___/| .__/|_|\__,_|
#                             |_|
#   bactopia v3.0.1
#   Bactopia is a flexible pipeline for complete analysis of bacterial genomes
# ---------------------------------------------
# Core Nextflow options
#   runName          : ridiculous_meninsky
#   container        : quay.io/bactopia/bactopia:3.0.1
#   launchDir        : /content/bactopia
#   workDir          : /content/bactopia/work
#   projectDir       : /usr/local/share/bactopia-3.0.1
#   userName         : root
#   profile          : standard
#   configFiles      : /usr/local/share/bactopia-3.0.1/nextflow.config
#
# Required Parameters
#   accessions       : bactopia-accessions.txt
#
# Dataset Parameters
#   genome_size      : 0
#
# QC Parameters
#   use_porechop     : false
#   adapters         : /usr/local/share/bactopia-3.0.1/data/EMPTY_ADAPTERS
#   phix             : /usr/local/share/bactopia-3.0.1/data/EMPTY_PHIX
#
# Assembler Parameters
#   nanohq           : null
#
# Prokka Parameters
#   proteins         : /usr/local/share/bactopia-3.0.1/data/proteins.faa
#
# Optional Parameters
#   outdir           : ./Bactopia_results/
#
# Nextflow Configuration Parameters
#   cleanup_workdir  : true
#
# Nextflow Profile Parameters
#   condadir         : /root/.bactopia/conda
#   datasets_cache   : /root/.bactopia/datasets
#   singularity_cache: /root/.bactopia/singularity
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# --------------------------------------------------------------------
# If you use bactopia for your analysis please cite:
#
# * Bactopia
#   https://doi.org/10.1128/mSystems.00190-20
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://bactopia.github.io/acknowledgements/
# --------------------------------------------------------------------
# WARN:
# WARN: Conda Disclaimer
# WARN:
# WARN: If you have access to Docker or Singularity, please consider
# WARN: running Bactopia using containers. The containers are less
# WARN: susceptible to Conda environment related issues (e.g. version
# WARN: conflicts) and errors caused by creation of conda environments
# WARN: in parallel (use '--max_cpus 1' to over come this error).
# WARN:
# WARN: To use containers, you can use the profile parameter
# WARN:     Docker: -profile docker
# WARN:     Singularity: -profile singularity
# WARN:
# --------------------------------------------------------------------
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
# WARN: Maximum memory (32) was adjusted to fit your system (12)
# WARN: Maximum CPUs (4) was adjusted to fit your system (2)
#
# Each task will use 2 CPUs out of the available 2 CPUs. At most
# 1 task(s) will be run at a time, this can affect the efficiency
# of Bactopia. You can use the '-qs' parameter to alter the number of
# tasks to run at a time (e.g. '-qs 2', means only 2 tasks or a maximum
# of 4 CPUs will be used at once)
#
#
# [-        ] process > BACTOPIA:DATASETS -
#
# [-        ] process > BACTOPIA:DATASETS              -
# [-        ] process > BACTOPIA:GATHER:GATHER_MODULE  -
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
#
# [-        ] process > BACTOPIA:DATASETS              -
# [-        ] process > BACTOPIA:GATHER:GATHER_MODULE  -
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
#
# [-        ] process > BACTOPIA:DATASETS              -
# [-        ] process > BACTOPIA:GATHER:GATHER_MODULE  -
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1
# [-        ] process > BACTOPIA:GATHER:GATHER_MODULE  -
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
# [skipping] Stored process > BACTOPIA:DATASETS
#
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [-        ] process > BACTOPIA:GATHER:GATHER_MODULE  [  0%] 0 of 2
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
# [skipping] Stored process > BACTOPIA:DATASETS
#
# executor >  local (1)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [6a/3331cd] process > BACTOPIA:GATHER:GATHER_MODU... [  0%] 0 of 2
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
# [skipping] Stored process > BACTOPIA:DATASETS
#
# executor >  local (2)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [  0%] 0 of 2
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
#
# executor >  local (2)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [6a/3331cd] process > BACTOPIA:GATHER:GATHER_MODU... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          -
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
#
# executor >  local (2)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [6a/3331cd] process > BACTOPIA:GATHER:GATHER_MODU... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [-        ] process > BACTOPIA:QC:QC_MODULE          [  0%] 0 of 1
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (3)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   -
# [0c/28cf43] process > BACTOPIA:QC:QC_MODULE (SRX2... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (3)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   [  0%] 0 of 1
# [0c/28cf43] process > BACTOPIA:QC:QC_MODULE (SRX2... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (4)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   [  0%] 0 of 1
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (4)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   [  0%] 0 of 1
# [0c/28cf43] process > BACTOPIA:QC:QC_MODULE (SRX2... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... -
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (4)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:GATHER:CSVTK_CONCAT   [  0%] 0 of 1
# [0c/28cf43] process > BACTOPIA:QC:QC_MODULE (SRX2... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [  0%] 0 of 1
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (5)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [  0%] 0 of 1
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (6)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [a9/682ee2] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (7)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      -
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (7)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [a9/682ee2] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... -
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      [  0%] 0 of 1
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (7)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [a9/682ee2] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... [  0%] 0 of 1
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [-        ] process > BACTOPIA:MLST:MLST_MODULE      [  0%] 0 of 1
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (8)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [a9/682ee2] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... [  0%] 0 of 1
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [  0%] 0 of 1
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (8)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [a9/682ee2] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... -
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [  0%] 0 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (8)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [-        ] process > BACTOPIA:SKETCHER:SKETCHER_... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [  0%] 0 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (9)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [c8/d7c0d4] process > BACTOPIA:SKETCHER:SKETCHER_... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [  0%] 0 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (9)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [c8/d7c0d4] process > BACTOPIA:SKETCHER:SKETCHER_... [  0%] 0 of 2
# [-        ] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (10)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [c8/d7c0d4] process > BACTOPIA:SKETCHER:SKETCHER_... [ 50%] 1 of 2
# [50/fb9161] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (11)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [ 50%] 1 of 2
# [50/fb9161] process > BACTOPIA:ANNOTATOR:PROKKA_M... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (11)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [ 50%] 1 of 2
# [50/fb9161] process > BACTOPIA:ANNOTATOR:PROKKA_M... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [d8/e87703] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (12)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [ 50%] 1 of 2
# [50/fb9161] process > BACTOPIA:ANNOTATOR:PROKKA_M... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (12)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [50/fb9161] process > BACTOPIA:ANNOTATOR:PROKKA_M... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (13)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [ 50%] 1 of 2 ✔
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     -
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (13)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     [  0%] 0 of 1
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (14)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     [  0%] 0 of 1
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (14)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [  0%] 0 of 1
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     [  0%] 0 of 1
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (15)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [00/2f3b23] process > BACTOPIA:AMRFINDERPLUS:AMRF... [  0%] 0 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:MLST:CSVTK_CONCAT     [  0%] 0 of 1
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (16)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [00/2f3b23] process > BACTOPIA:AMRFINDERPLUS:AMRF... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [  0%] 0 of 1
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  -
#
# executor >  local (16)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [00/2f3b23] process > BACTOPIA:AMRFINDERPLUS:AMRF... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [  0%] 0 of 1
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  [  0%] 0 of 1
#
# executor >  local (17)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [ 50%] 1 of 2
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... -
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [-        ] process > BACTOPIA:DUMPSOFTWAREVERSIONS  [  0%] 0 of 1
#
# executor >  local (18)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... -
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [7f/8cf28c] process > BACTOPIA:DUMPSOFTWAREVERSIO... [  0%] 0 of 1
#
# executor >  local (18)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [100%] 2 of 2 ✔
# [-        ] process > BACTOPIA:AMRFINDERPLUS:GENE... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... [  0%] 0 of 1
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [7f/8cf28c] process > BACTOPIA:DUMPSOFTWAREVERSIO... [  0%] 0 of 1
#
# executor >  local (19)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [100%] 2 of 2 ✔
# [3e/720f5f] process > BACTOPIA:AMRFINDERPLUS:GENE... [  0%] 0 of 1
# [-        ] process > BACTOPIA:AMRFINDERPLUS:PROT... [  0%] 0 of 1
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [7f/8cf28c] process > BACTOPIA:DUMPSOFTWAREVERSIO... [100%] 1 of 1 ✔
#
# executor >  local (20)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [100%] 2 of 2 ✔
# [3e/720f5f] process > BACTOPIA:AMRFINDERPLUS:GENE... [100%] 1 of 1 ✔
# [4c/1d79e4] process > BACTOPIA:AMRFINDERPLUS:PROT... [  0%] 0 of 1
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [7f/8cf28c] process > BACTOPIA:DUMPSOFTWAREVERSIO... [100%] 1 of 1 ✔
#
# executor >  local (20)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [100%] 2 of 2 ✔
# [3e/720f5f] process > BACTOPIA:AMRFINDERPLUS:GENE... [100%] 1 of 1 ✔
# [4c/1d79e4] process > BACTOPIA:AMRFINDERPLUS:PROT... [100%] 1 of 1 ✔
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [7f/8cf28c] process > BACTOPIA:DUMPSOFTWAREVERSIO... [100%] 1 of 1 ✔
#
#     Bactopia Execution Summary
#     ---------------------------
#     Bactopia Version : 3.0.1
#     Nextflow Version : 23.10.1
#     Command Line     : nextflow run /usr/local//share/bactopia-3.0.1/main.nf -w /content/bactopia/work/ --accessions bactopia-accessions.txt --outdir ./Bactopia_results/ --cleanup_workdir --cpus 8
#     Resumed          : false
#     Completed At     : 2024-02-02T03:53:33.940195178Z
#     Duration         : 1h 45m 25s
#     Success          : true
#     Exit Code        : 0
#     Error Report     : -
#     Launch Dir       : /content/bactopia
#
#
# executor >  local (20)
# [skipped  ] process > BACTOPIA:DATASETS              [100%] 1 of 1, stored: 1 ✔
# [4b/e70653] process > BACTOPIA:GATHER:GATHER_MODU... [100%] 2 of 2 ✔
# [ef/7ba40f] process > BACTOPIA:GATHER:CSVTK_CONCA... [100%] 1 of 1 ✔
# [70/421d43] process > BACTOPIA:QC:QC_MODULE (SRX2... [100%] 2 of 2 ✔
# [99/174f46] process > BACTOPIA:ASSEMBLER:ASSEMBLE... [100%] 2 of 2 ✔
# [80/6531cb] process > BACTOPIA:ASSEMBLER:CSVTK_CO... [100%] 1 of 1 ✔
# [b6/e869a1] process > BACTOPIA:SKETCHER:SKETCHER_... [100%] 2 of 2 ✔
# [96/01cf94] process > BACTOPIA:ANNOTATOR:PROKKA_M... [100%] 2 of 2 ✔
# [02/1f9708] process > BACTOPIA:AMRFINDERPLUS:AMRF... [100%] 2 of 2 ✔
# [3e/720f5f] process > BACTOPIA:AMRFINDERPLUS:GENE... [100%] 1 of 1 ✔
# [4c/1d79e4] process > BACTOPIA:AMRFINDERPLUS:PROT... [100%] 1 of 1 ✔
# [16/d2df63] process > BACTOPIA:MLST:MLST_MODULE (... [100%] 2 of 2 ✔
# [2f/1e5a0f] process > BACTOPIA:MLST:CSVTK_CONCAT ... [100%] 1 of 1 ✔
# [7f/8cf28c] process > BACTOPIA:DUMPSOFTWAREVERSIO... [100%] 1 of 1 ✔
#
#     Bactopia Execution Summary
#     ---------------------------
#     Bactopia Version : 3.0.1
#     Nextflow Version : 23.10.1
#     Command Line     : nextflow run /usr/local//share/bactopia-3.0.1/main.nf -w /content/bactopia/work/ --accessions bactopia-accessions.txt --outdir ./Bactopia_results/ --cleanup_workdir --cpus 8
#     Resumed          : false
#     Completed At     : 2024-02-02T03:53:33.940195178Z
#     Duration         : 1h 45m 25s
#     Success          : true
#     Exit Code        : 0
#     Error Report     : -
#     Launch Dir       : /content/bactopia
#
# Completed at: 02-Feb-2024 03:53:36
# Duration    : 1h 45m 26s
# CPU hours   : 3.5
# Succeeded   : 20
#
#
# Bactopia finished successfully! Found '--cleanup_workdir' removing '/content/bactopia/work/'

# %% [markdown]
# ##Now if the sequences comes from Oxford Nanopore Technologies (ONT), we use the following command

# %%
bactopia --ont --accessions bactopia-accessions.txt --outdir ./pepe/ --cleanup_workdir

# %% [markdown]
# ## Lets move the Bactopia_results folder to your course folder the Google Drive

# %%
import shutil

# Source and destination paths
source_path = '/content/bactopia/Bactopia_results'
destination_path = '/content/gdrive/Shareddrives/Bacterial_bioinformatics_workshop/Day_2/Bactopia'

# Move the folder
shutil.move(source_path, destination_path)
# Out:
# '/content/gdrive/Shareddrives/Workshop Manuel & Alba/Day_2/Bactopia'

# %% [markdown]
# # Finally, this code will be useful to quickly remove a non-empty directory

# %%
# Go back one folder to remove the virtual "bactopia" folder
# !cd ..
# Out:
# /

# %%
import shutil

# Replace 'your_directory' with the actual path of the directory you want to delete
directory_path = 'bactopia'

# Delete the directory and its contents
shutil.rmtree(directory_path)
