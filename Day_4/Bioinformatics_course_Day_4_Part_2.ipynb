# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelncsu/Bacterial-WGS-bioinformatics-workshop/blob/main/Day_4/Bioinformatics_course_Day_4_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Bacterial WGS bioinformatics workshop**
# ## **Day 4 - Part 2.** Pangenome Genome Wide Association Studies (pan-GWAS) analysis using Scoary

# %% [markdown]
# ##**Step 1:** Mounting your google drive into google colab

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/gdrive/

# %% [markdown]
# ##Lets check if it works!

# %%
ls
# Out:
# gdrive/  sample_data/

# %% [markdown]
# ##Lets go to the workshop main folder

# %%
cd /content/gdrive/Shareddrives/Bacterial_bioinformatics_workshop/Day_4/Part_2
# Out:
# /content/gdrive/Shareddrives/Workshop Manuel & Alba/Day_4/Part_2

# %%
ls
# Out:
# 'Bioinformatics course_Day 4-Part_2'   condacolab_install.log   scoary/

# %% [markdown]
# ##Install Conda

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %% [markdown]
# ##Verify Conda installation

# %%
# !conda --version
# Out:
# conda 23.1.0

# %%
# !ls
# Out:
# 'Bioinformatics course_Day 4-Part_2'   condacolab_install.log   scoary

# %% [markdown]
# ## Lets create a virtual environment

# %%
# !python --version
# Out:
# Python 3.10.10

# %%
# !pwd
# Out:
# /content/gdrive/Shareddrives/Workshop Manuel & Alba/Day_4/Part_2

# %%
# install virtual environment package
# !pip install virtualenv

# %%
# create virtual environment
# !virtualenv scoary

# %%
# Lets check our new virtual environment
# !ls
# Out:
# bin  lib  pyvenv.cfg

# %%
#Activate the environment
# !source scoary/bin/activate

# %%
cd scoary
# Out:
# /content/gdrive/Shareddrives/Workshop Manuel & Alba/Day_4/Part_2/scoary

# %% [markdown]
# # Lets install Scoary

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Link to the article: https://link.springer.com/article/10.1186/s13059-016-1108-8

# %%
# !pip install scoary

# %%
# !pip install scipy==1.7.3

# %% [markdown]
# ## Before running Scoary, we should:
#
# *   Copy the previously generated gene presence/absence matrix generated with   Panaroo into our working directory
#
# *   Based on our gene presence/absence matrix, lets select some genes to analyse (Check the provided example data).

# %%
# !scoary -g gene_presence_absence_roary.csv -t traits_data.csv -o C_difficile_results

# %%
# !ls
# Out:
#  bin				       Gene_presence_absence.csv
#  blaCDD_07_02_2024_0243.results.csv    gene_presence_absence_roary.csv
#  C_difficile_results		       lib
#  cdtA_07_02_2024_0243.results.csv      Scoary_output_table.csv
# 'cfr(C)_07_02_2024_0243.results.csv'   Tetracycline_resistance.csv
# 'erm(B)_07_02_2024_0243.results.csv'   traits_data.csv
#  Example_results		       vanZ1_07_02_2024_0243.results.csv

# %% [markdown]
# ## Checking our results (*C. difficile*)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("C_difficile_results/erm(B)_07_02_2024_0331.results.csv") #You can change the name of the table you would like to visualize

# Display the DataFrame
df
# Out:
#          Gene       Non-unique Gene name  \
# 0        group_2828               NaN
# 1        group_2824               NaN
# 2        group_2795               NaN
# 3        group_2749               NaN
# 4        group_2717               NaN
# 5        group_2692               NaN
# 6        group_2691               NaN
# 7        group_2689               NaN
# 8        group_2601               NaN
# 9      maa_2~~~dapH        maa_2;dapH
# 10       group_2403               NaN
# 11       group_2391               NaN
# 12       group_2377               NaN
# 13       group_2125               NaN
# 14       group_1651               NaN
# 15       group_1417               NaN
# 16       group_1393               NaN
# 17       group_1197               NaN
# 18              erm               erm
# 19       group_1011               NaN
# 20        group_816               NaN
# 21            rep_2             rep_2
# 22           recF_2            recF_2
# ...

# %% [markdown]
# ## How to interpret the results table

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("Scoary_output_table.csv")

# Display the DataFrame
df
# Out:
#           Column name          \
# 0                        Gene
# 1        Non-unique gene name
# 2                  Annotation
# 3       Number_pos_present_in
# 4       Number_neg_present_in
# 5   Number_pos_not_present_in
# 6   Number_neg_not_present_in
# 7                 Sensitivity
# 8                 Specificity
# 9                  Odds_ratio
# 10                    p_value
# 11               Bonferroni_p
# 12              Benjamini_H_p
# 13   Max_pairwise_comparisons
# 14       Max_supporting_pairs
# 15         Max_opposing_pairs
# 16       Best_pairwise_comp_p
# 17      Worst_pairwise_comp_p
# 18                Empirical_p
#
#                       Explanation
# 0                                       The gene name
# 1                            The non-unique gene name
# 2                                          Annotation
# 3   The number of trait-positive isolates this gen...
# 4   The number of trait-negative isolates this gen...
# ...

# %% [markdown]
# ## Lets compare with the example dataset provided by Scoary

# %%
ls
# Out:
#  bin/                                  Gene_presence_absence.csv
#  blaCDD_07_02_2024_0243.results.csv    gene_presence_absence_roary.csv
#  C_difficile_results/                  lib/
#  cdtA_07_02_2024_0243.results.csv      Scoary_output_table.csv
# 'cfr(C)_07_02_2024_0243.results.csv'   Tetracycline_resistance.csv
# 'erm(B)_07_02_2024_0243.results.csv'   traits_data.csv
#  Example_results/                      vanZ1_07_02_2024_0243.results.csv

# %%
# !scoary -g Gene_presence_absence.csv -t Tetracycline_resistance.csv -o Example_results

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("Example_results/Tetracycline_resistance_07_02_2024_0329.results.csv") #You can change the name of the table you would like to visualize

# Display the DataFrame
df
# Out:
#        Gene     Non-unique Gene name  \
# 0       TetRCG          NaN
# 1    gene_8004          NaN
# 2    gene_4006          NaN
# 3    gene_4449          NaN
# 4    gene_6326          NaN
# ..         ...                   ...
# 332  gene_3812          NaN
# 333  gene_5725          NaN
# 334  gene_6271          NaN
# 335  gene_8965          NaN
# 336  gene_3227          NaN
#
#                         Annotation                      Number_pos_present_in  \
# 0    A fictitious gene known to cause resistance ag...           29
# 1    A gene with no relevance to tetracycline resis...           23
# 2    A gene with no relevance to tetracycline resis...           24
# 3    A gene with no relevance to tetracycline resis...           23
# 4    A gene with no relevance to tetracycline resis...           10
# ..                                                 ...                    ...
# 332  A gene with no relevance to tetracycline resis...           18
# ...
