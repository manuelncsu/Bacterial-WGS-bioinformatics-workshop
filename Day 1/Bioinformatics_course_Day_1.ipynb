# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelncsu/Bacterial-WGS-bioinformatics-workshop/blob/main/Bacterial-WGS-bioinformatics-workshop/Bioinformatics_course_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Lanzas_lab_logo_v2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Bacterial WGS bioinformatics workshop**
# ## **Day 1.** Data Search and fetching metadata

# %% [markdown]
# ##**Step 1:** Mounting your google drive into google colab

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# ##Lets check if it works!

# %%
ls
# Out:
# gdrive/  sample_data/

# %% [markdown]
# ##Lets go to the workshop main folder

# %%
cd /content/gdrive/Shareddrives/Workshop Manuel & Alba

# %%
ls
# Out:
# 'Bioinformatics course'   'Course Organization.gdoc'     SRA_sequences.txt
#  condacolab_install.log    Lanzas_lab_logo_v2.jpg        SRA_subsample_metadata.txt
# 'Course content.gslides'   SRA_sequences_subsample.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ##**Step 2:** Lets check if some needed software are installed

# %% [markdown]
# ##Install Conda

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %% [markdown]
# ##Verify Conda installation

# %%
# !conda --version
# Out:
# conda 23.1.0

# %% [markdown]
# ##Lets install some necessary packages in your Conda environment

# %%
# !conda install pandas numpy matplotlib

# %% [markdown]
# ##Install Biopython

# %%
# !pip3 install biopython

# %% [markdown]
# # **Step 3:** Getting familiar with NCBI
# ### Install the required packages

# %%
# !apt-get update
# !apt-get install ncbi-entrez-utils

# %%
# !apt-get update

# %%
# !apt-get install --reinstall libcurl4-openssl-dev

# %%
# !apt-get install -y ncbi-entrez-direct

# %%
from Bio import Entrez

# %% [markdown]
# ##Try this command to check that esearch works

# %%
# !esearch -db bioproject -query PRJNA344770
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# <ENTREZ_DIRECT>
#   <Db>bioproject</Db>
#   <WebEnv>MCID_65bbafe0b1324f1d3a414d91</WebEnv>
#   <QueryKey>1</QueryKey>
#   <Count>1</Count>
#   <Step>1</Step>
# </ENTREZ_DIRECT>

# %% [markdown]
# ##Perform the initial search and save the sequences to a file

# %%
#Check our working directory
# !pwd
# Out:
# /content/gdrive/Shareddrives/Workshop Manuel & Alba

# %%
# !esearch -db sra -query 'PRJNA344770' | efetch -format docsum | grep SRR | cut -d '"' -f 2 > SRA_sequences.txt
# Out:
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)
# curl: /usr/local/lib/libcurl.so.4: no version information available (required by curl)

# %%
ls
# Out:
# 'Bioinformatics course'  'Course content.gslides'     Lanzas_lab_logo_v2.jpg
#  condacolab_install.log  'Course Organization.gdoc'   SRA_sequences.txt

# %% [markdown]
# ##Once the .txt file was generated, you can read the first 10 lines using the following code

# %%
# Specify the file name
file_name = "SRA_sequences.txt"

# Read the first 10 lines
with open(file_name, "r") as file:
    for i in range(10):
        line = file.readline()
        print(line)
# Out:
# SRR4300580
#
# SRR4300579
#
# SRR4300578
#
# SRR4300577
#
# SRR4300576
#
# SRR4300575
#
# SRR4300574
#
# SRR4300573
#
# SRR4300572
#
# SRR4300571

# %% [markdown]
# ##Create a subsample file with the first 30 sequences

# %%
input_file_path = 'SRA_sequences.txt'
output_file_path = 'SRA_sequences_subsample.txt'

# Open the input file and read the first 30 lines
with open(input_file_path, 'r') as input_file:
    lines_to_keep = [next(input_file) for _ in range(30)]

# Open the output file and write the selected lines
with open(output_file_path, 'w') as output_file:
    output_file.writelines(lines_to_keep)

# %%
ls
# Out:
# 'Bioinformatics course'   'Course Organization.gdoc'     SRA_sequences.txt
#  condacolab_install.log    Lanzas_lab_logo_v2.jpg
# 'Course content.gslides'   SRA_sequences_subsample.txt

# %% [markdown]
# ##Fetch metadata for a list of SRA sequences

# %%
# !xargs -a SRA_sequences_subsample.txt -I {} efetch -db sra -id {} -format runinfo >> SRA_subsample_metadata.txt

# %%
ls
# Out:
# 'Bioinformatics course'   'Course Organization.gdoc'     SRA_sequences.txt
#  condacolab_install.log    Lanzas_lab_logo_v2.jpg        SRA_subsample_metadata.txt
# 'Course content.gslides'   SRA_sequences_subsample.txt

# %% [markdown]
# ##To check the extracted metadata as table

# %%
import pandas as pd

# Add the path to your file
file_path = 'SRA_subsample_metadata.txt'

# Read the entire file into a Pandas DataFrame
df = pd.read_csv(file_path, sep=',')

# Load the data_table extension for interactive display
# %load_ext google.colab.data_table

# Display the DataFrame
df
# Out:
# Warning: Total number of columns (47) exceeds max_columns (20). Falling back to pandas display.
#            Run          ReleaseDate             LoadDate    spots       bases  \
# 0   SRR4300580  2016-10-04 15:02:29  2016-09-29 15:00:24   925431   557109462
# 1          Run          ReleaseDate             LoadDate    spots       bases
# 2   SRR4300579  2016-10-04 15:12:02  2016-09-29 15:07:50  2138327  1287272854
# 3          Run          ReleaseDate             LoadDate    spots       bases
# 4   SRR4300578  2016-10-04 15:12:02  2016-09-29 15:02:33  1459659   878714718
# 5          Run          ReleaseDate             LoadDate    spots       bases
# 6   SRR4300577  2016-10-04 15:12:16  2016-09-29 15:02:35  2663100  1603186200
# 7          Run          ReleaseDate             LoadDate    spots       bases
# 8   SRR4300576  2016-10-04 15:12:08  2016-09-29 15:02:25  3207599  1930974598
# 9          Run          ReleaseDate             LoadDate    spots       bases
# 10  SRR4300575  2016-10-04 15:04:41  2016-09-29 15:01:15  2235111  1345536822
# 11         Run          ReleaseDate             LoadDate    spots       bases
# 12  SRR4300574  2016-10-04 15:00:43  2016-09-29 14:59:46   628449   378326298
# 13         Run          ReleaseDate             LoadDate    spots       bases
# 14  SRR4300573  2016-10-04 15:04:50  2016-09-29 15:01:27  2047656  1232688912
# 15         Run          ReleaseDate             LoadDate    spots       bases
# 16  SRR4300572  2016-10-04 15:11:51  2016-09-29 15:03:28  1174583   707098966
# 17         Run          ReleaseDate             LoadDate    spots       bases
# 18  SRR4300571  2016-10-04 15:02:30  2016-09-29 15:00:52  1845501  1110991602
# 19         Run          ReleaseDate             LoadDate    spots       bases
# 20  SRR4300570  2016-10-04 15:02:30  2016-09-29 15:00:43  1947285  1172265570
# 21         Run          ReleaseDate             LoadDate    spots       bases
# 22  SRR4300569  2016-10-04 15:04:48  2016-09-29 15:01:49  3152988  1898098776
# 23         Run          ReleaseDate             LoadDate    spots       bases
# 24  SRR4300568  2016-10-04 15:02:29  2016-09-29 15:00:53  2160117  1300390434
# 25         Run          ReleaseDate             LoadDate    spots       bases
# 26  SRR4300567  2016-10-04 15:02:08  2016-09-29 15:00:19  1463743   881173286
# 27         Run          ReleaseDate             LoadDate    spots       bases
# 28  SRR4300566  2016-10-04 15:12:01  2016-09-29 15:03:35  2253499  1356606398
# 29         Run          ReleaseDate             LoadDate    spots       bases
# 30  SRR4300565  2016-10-04 15:00:48  2016-09-29 15:00:04  1166267   702092734
# 31         Run          ReleaseDate             LoadDate    spots       bases
# 32  SRR4300564  2016-10-04 15:11:49  2016-09-29 15:04:40  1624487   977941174
# 33         Run          ReleaseDate             LoadDate    spots       bases
# 34  SRR4300563  2016-10-04 15:02:11  2016-09-29 15:01:00  1972941  1187710482
# 35         Run          ReleaseDate             LoadDate    spots       bases
# 36  SRR4300562  2016-10-04 15:00:54  2016-09-29 15:00:07  1649613   993067026
# 37         Run          ReleaseDate             LoadDate    spots       bases
# 38  SRR4300561  2016-10-04 15:04:47  2016-09-29 15:01:21  2839121  1709150842
# 39         Run          ReleaseDate             LoadDate    spots       bases
# 40  SRR4300560  2016-10-04 15:05:04  2016-09-29 15:01:47  3534642  2127854484
# 41         Run          ReleaseDate             LoadDate    spots       bases
# 42  SRR4300559  2016-10-04 15:02:30  2016-09-29 15:01:04  2710366  1631640332
# 43         Run          ReleaseDate             LoadDate    spots       bases
# 44  SRR4300558  2016-10-04 15:12:18  2016-09-29 15:03:19  3158529  1901434458
# 45         Run          ReleaseDate             LoadDate    spots       bases
# 46  SRR4300557  2016-10-04 15:05:01  2016-09-29 15:02:01  3840618  2312052036
# 47         Run          ReleaseDate             LoadDate    spots       bases
# 48  SRR4300556  2016-10-04 15:00:54  2016-09-29 14:59:53  1685182  1014479564
# 49         Run          ReleaseDate             LoadDate    spots       bases
# 50  SRR4300555  2016-10-04 15:12:18  2016-09-29 15:02:13  4361747  2625771694
# 51         Run          ReleaseDate             LoadDate    spots       bases
# 52  SRR4300554  2016-10-04 15:04:50  2016-09-29 15:01:22  2999917  1805950034
# 53         Run          ReleaseDate             LoadDate    spots       bases
# 54  SRR4300553  2016-10-04 15:12:17  2016-09-29 15:02:24  3727682  2244064564
# 55         Run          ReleaseDate             LoadDate    spots       bases
# 56  SRR4300552  2016-10-04 15:02:29  2016-09-29 15:01:03  2714189  1633941778
# 57         Run          ReleaseDate             LoadDate    spots       bases
# 58  SRR4300551  2016-10-04 15:02:05  2016-09-29 15:00:18  2268566  1365676732
#
#     spots_with_mates  avgLength  size_MB  AssemblyName  \
# 0             925431        602      302           NaN
# 1   spots_with_mates  avgLength  size_MB  AssemblyName
# 2            2138327        602      663           NaN
# 3   spots_with_mates  avgLength  size_MB  AssemblyName
# 4            1459659        602      418           NaN
# 5   spots_with_mates  avgLength  size_MB  AssemblyName
# 6            2663100        602      773           NaN
# 7   spots_with_mates  avgLength  size_MB  AssemblyName
# 8            3207599        602      957           NaN
# 9   spots_with_mates  avgLength  size_MB  AssemblyName
# 10           2235111        602      643           NaN
# 11  spots_with_mates  avgLength  size_MB  AssemblyName
# 12            628449        602      171           NaN
# 13  spots_with_mates  avgLength  size_MB  AssemblyName
# 14           2047656        602      558           NaN
# 15  spots_with_mates  avgLength  size_MB  AssemblyName
# 16           1174583        602      338           NaN
# 17  spots_with_mates  avgLength  size_MB  AssemblyName
# 18           1845501        602      499           NaN
# 19  spots_with_mates  avgLength  size_MB  AssemblyName
# 20           1947285        602      535           NaN
# 21  spots_with_mates  avgLength  size_MB  AssemblyName
# 22           3152988        602      874           NaN
# 23  spots_with_mates  avgLength  size_MB  AssemblyName
# 24           2160117        602      593           NaN
# 25  spots_with_mates  avgLength  size_MB  AssemblyName
# 26           1463743        602      426           NaN
# 27  spots_with_mates  avgLength  size_MB  AssemblyName
# 28           2253499        602      619           NaN
# 29  spots_with_mates  avgLength  size_MB  AssemblyName
# 30           1166267        602      335           NaN
# 31  spots_with_mates  avgLength  size_MB  AssemblyName
# 32           1624487        602      532           NaN
# 33  spots_with_mates  avgLength  size_MB  AssemblyName
# 34           1972941        602      657           NaN
# 35  spots_with_mates  avgLength  size_MB  AssemblyName
# 36           1649613        602      538           NaN
# 37  spots_with_mates  avgLength  size_MB  AssemblyName
# 38           2839121        602      919           NaN
# 39  spots_with_mates  avgLength  size_MB  AssemblyName
# 40           3534642        602     1204           NaN
# 41  spots_with_mates  avgLength  size_MB  AssemblyName
# 42           2710366        602      884           NaN
# 43  spots_with_mates  avgLength  size_MB  AssemblyName
# 44           3158529        602     1088           NaN
# 45  spots_with_mates  avgLength  size_MB  AssemblyName
# 46           3840618        602     1240           NaN
# 47  spots_with_mates  avgLength  size_MB  AssemblyName
# 48           1685182        602      496           NaN
# 49  spots_with_mates  avgLength  size_MB  AssemblyName
# 50           4361747        602     1437           NaN
# 51  spots_with_mates  avgLength  size_MB  AssemblyName
# 52           2999917        602      939           NaN
# 53  spots_with_mates  avgLength  size_MB  AssemblyName
# 54           3727682        602     1229           NaN
# 55  spots_with_mates  avgLength  size_MB  AssemblyName
# 56           2714189        602      849           NaN
# 57  spots_with_mates  avgLength  size_MB  AssemblyName
# 58           2268566        602      710           NaN
#
#                                         download_path  ...  Affection_Status  \
# 0   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 1                                       download_path  ...  Affection_Status
# 2   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 3                                       download_path  ...  Affection_Status
# 4   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 5                                       download_path  ...  Affection_Status
# 6   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 7                                       download_path  ...  Affection_Status
# 8   https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 9                                       download_path  ...  Affection_Status
# 10  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 11                                      download_path  ...  Affection_Status
# 12  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 13                                      download_path  ...  Affection_Status
# 14  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 15                                      download_path  ...  Affection_Status
# 16  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 17                                      download_path  ...  Affection_Status
# 18  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 19                                      download_path  ...  Affection_Status
# 20  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 21                                      download_path  ...  Affection_Status
# 22  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 23                                      download_path  ...  Affection_Status
# 24  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 25                                      download_path  ...  Affection_Status
# 26  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 27                                      download_path  ...  Affection_Status
# 28  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 29                                      download_path  ...  Affection_Status
# 30  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 31                                      download_path  ...  Affection_Status
# 32  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 33                                      download_path  ...  Affection_Status
# 34  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 35                                      download_path  ...  Affection_Status
# 36  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 37                                      download_path  ...  Affection_Status
# 38  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 39                                      download_path  ...  Affection_Status
# 40  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 41                                      download_path  ...  Affection_Status
# 42  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 43                                      download_path  ...  Affection_Status
# 44  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 45                                      download_path  ...  Affection_Status
# 46  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 47                                      download_path  ...  Affection_Status
# 48  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 49                                      download_path  ...  Affection_Status
# 50  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 51                                      download_path  ...  Affection_Status
# 52  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 53                                      download_path  ...  Affection_Status
# 54  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 55                                      download_path  ...  Affection_Status
# 56  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
# 57                                      download_path  ...  Affection_Status
# 58  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...               NaN
#
#     Analyte_Type  Histological_Type  Body_Site           CenterName  \
# 0            NaN                NaN        NaN  STANFORD UNIVERSITY
# 1   Analyte_Type  Histological_Type  Body_Site           CenterName
# 2            NaN                NaN        NaN  STANFORD UNIVERSITY
# 3   Analyte_Type  Histological_Type  Body_Site           CenterName
# 4            NaN                NaN        NaN  STANFORD UNIVERSITY
# 5   Analyte_Type  Histological_Type  Body_Site           CenterName
# 6            NaN                NaN        NaN  STANFORD UNIVERSITY
# 7   Analyte_Type  Histological_Type  Body_Site           CenterName
# 8            NaN                NaN        NaN  STANFORD UNIVERSITY
# 9   Analyte_Type  Histological_Type  Body_Site           CenterName
# 10           NaN                NaN        NaN  STANFORD UNIVERSITY
# 11  Analyte_Type  Histological_Type  Body_Site           CenterName
# 12           NaN                NaN        NaN  STANFORD UNIVERSITY
# 13  Analyte_Type  Histological_Type  Body_Site           CenterName
# 14           NaN                NaN        NaN  STANFORD UNIVERSITY
# 15  Analyte_Type  Histological_Type  Body_Site           CenterName
# 16           NaN                NaN        NaN  STANFORD UNIVERSITY
# 17  Analyte_Type  Histological_Type  Body_Site           CenterName
# 18           NaN                NaN        NaN  STANFORD UNIVERSITY
# 19  Analyte_Type  Histological_Type  Body_Site           CenterName
# 20           NaN                NaN        NaN  STANFORD UNIVERSITY
# 21  Analyte_Type  Histological_Type  Body_Site           CenterName
# 22           NaN                NaN        NaN  STANFORD UNIVERSITY
# 23  Analyte_Type  Histological_Type  Body_Site           CenterName
# 24           NaN                NaN        NaN  STANFORD UNIVERSITY
# 25  Analyte_Type  Histological_Type  Body_Site           CenterName
# 26           NaN                NaN        NaN  STANFORD UNIVERSITY
# 27  Analyte_Type  Histological_Type  Body_Site           CenterName
# 28           NaN                NaN        NaN  STANFORD UNIVERSITY
# 29  Analyte_Type  Histological_Type  Body_Site           CenterName
# 30           NaN                NaN        NaN  STANFORD UNIVERSITY
# 31  Analyte_Type  Histological_Type  Body_Site           CenterName
# 32           NaN                NaN        NaN  STANFORD UNIVERSITY
# 33  Analyte_Type  Histological_Type  Body_Site           CenterName
# 34           NaN                NaN        NaN  STANFORD UNIVERSITY
# 35  Analyte_Type  Histological_Type  Body_Site           CenterName
# 36           NaN                NaN        NaN  STANFORD UNIVERSITY
# 37  Analyte_Type  Histological_Type  Body_Site           CenterName
# 38           NaN                NaN        NaN  STANFORD UNIVERSITY
# 39  Analyte_Type  Histological_Type  Body_Site           CenterName
# 40           NaN                NaN        NaN  STANFORD UNIVERSITY
# 41  Analyte_Type  Histological_Type  Body_Site           CenterName
# 42           NaN                NaN        NaN  STANFORD UNIVERSITY
# 43  Analyte_Type  Histological_Type  Body_Site           CenterName
# 44           NaN                NaN        NaN  STANFORD UNIVERSITY
# 45  Analyte_Type  Histological_Type  Body_Site           CenterName
# 46           NaN                NaN        NaN  STANFORD UNIVERSITY
# 47  Analyte_Type  Histological_Type  Body_Site           CenterName
# 48           NaN                NaN        NaN  STANFORD UNIVERSITY
# 49  Analyte_Type  Histological_Type  Body_Site           CenterName
# 50           NaN                NaN        NaN  STANFORD UNIVERSITY
# 51  Analyte_Type  Histological_Type  Body_Site           CenterName
# 52           NaN                NaN        NaN  STANFORD UNIVERSITY
# 53  Analyte_Type  Histological_Type  Body_Site           CenterName
# 54           NaN                NaN        NaN  STANFORD UNIVERSITY
# 55  Analyte_Type  Histological_Type  Body_Site           CenterName
# 56           NaN                NaN        NaN  STANFORD UNIVERSITY
# 57  Analyte_Type  Histological_Type  Body_Site           CenterName
# 58           NaN                NaN        NaN  STANFORD UNIVERSITY
#
#     Submission  dbgap_study_accession  Consent  \
# 0    SRA480763                    NaN   public
# 1   Submission  dbgap_study_accession  Consent
# 2    SRA480763                    NaN   public
# 3   Submission  dbgap_study_accession  Consent
# 4    SRA480763                    NaN   public
# 5   Submission  dbgap_study_accession  Consent
# 6    SRA480763                    NaN   public
# 7   Submission  dbgap_study_accession  Consent
# 8    SRA480763                    NaN   public
# 9   Submission  dbgap_study_accession  Consent
# 10   SRA480763                    NaN   public
# 11  Submission  dbgap_study_accession  Consent
# 12   SRA480763                    NaN   public
# 13  Submission  dbgap_study_accession  Consent
# 14   SRA480763                    NaN   public
# 15  Submission  dbgap_study_accession  Consent
# 16   SRA480763                    NaN   public
# 17  Submission  dbgap_study_accession  Consent
# 18   SRA480763                    NaN   public
# 19  Submission  dbgap_study_accession  Consent
# 20   SRA480763                    NaN   public
# 21  Submission  dbgap_study_accession  Consent
# 22   SRA480763                    NaN   public
# 23  Submission  dbgap_study_accession  Consent
# 24   SRA480763                    NaN   public
# 25  Submission  dbgap_study_accession  Consent
# 26   SRA480763                    NaN   public
# 27  Submission  dbgap_study_accession  Consent
# 28   SRA480763                    NaN   public
# 29  Submission  dbgap_study_accession  Consent
# 30   SRA480763                    NaN   public
# 31  Submission  dbgap_study_accession  Consent
# 32   SRA480763                    NaN   public
# 33  Submission  dbgap_study_accession  Consent
# 34   SRA480763                    NaN   public
# 35  Submission  dbgap_study_accession  Consent
# 36   SRA480763                    NaN   public
# 37  Submission  dbgap_study_accession  Consent
# 38   SRA480763                    NaN   public
# 39  Submission  dbgap_study_accession  Consent
# 40   SRA480763                    NaN   public
# 41  Submission  dbgap_study_accession  Consent
# 42   SRA480763                    NaN   public
# 43  Submission  dbgap_study_accession  Consent
# 44   SRA480763                    NaN   public
# 45  Submission  dbgap_study_accession  Consent
# 46   SRA480763                    NaN   public
# 47  Submission  dbgap_study_accession  Consent
# 48   SRA480763                    NaN   public
# 49  Submission  dbgap_study_accession  Consent
# 50   SRA480763                    NaN   public
# 51  Submission  dbgap_study_accession  Consent
# 52   SRA480763                    NaN   public
# 53  Submission  dbgap_study_accession  Consent
# 54   SRA480763                    NaN   public
# 55  Submission  dbgap_study_accession  Consent
# 56   SRA480763                    NaN   public
# 57  Submission  dbgap_study_accession  Consent
# 58   SRA480763                    NaN   public
#
#                              RunHash                          ReadHash
# 0   86ACAFFA7743D9D94E2C06B1CF0B9D9B  62208B65B54B53FC6B43805BF543B146
# 1                            RunHash                          ReadHash
# 2   2EF69F24E45C28F35F68E15635A6FD32  2BAE761A0FF395D11C9D0ADA5931A311
# 3                            RunHash                          ReadHash
# 4   71F19FF26240D44784DFED8467E0CB55  617B18A7579A8DEB812580AB99B67625
# 5                            RunHash                          ReadHash
# 6   B3A1996A6C394DFF2CBC1A104B8A4274  4E732FEBF9C113F77FF2C0745F0E5A30
# 7                            RunHash                          ReadHash
# 8   B7D02D591EED700A70F35FFDEA7A8C4A  DC05D4CA311A29BBDAD013D7C9918FFA
# 9                            RunHash                          ReadHash
# 10  47AD8C0BDD08FF561404E9288AB4406E  994DDAEB3C2AA0D97D190D158225BDBA
# 11                           RunHash                          ReadHash
# 12  165F883CA3BFD5352FFA476604D519F2  06E8DFD1A20174BAD6505B58EFDAAF81
# 13                           RunHash                          ReadHash
# 14  8A9179DFE7722FC2063C7F25AAB0C2A4  5378C796DADEAEDE08B9F9A28CCE1BE8
# 15                           RunHash                          ReadHash
# 16  762C77870B5E6820837466CBB257BA51  FAC999E516DAF96997E4A7A8344C2391
# 17                           RunHash                          ReadHash
# 18  8A99257DF6AF9DD6A756EB0871DB357D  90C6CD63F6FEA610A685E17DF895F26E
# 19                           RunHash                          ReadHash
# 20  6FE26DD7470BCEE0D4785F27B97C26B0  1D156E91D7396DAF8C9729DF1E474CC4
# 21                           RunHash                          ReadHash
# 22  5D210C09FB06FFA2213163567817E626  38E65EDE9D964512D6A0358BEFDD79CD
# 23                           RunHash                          ReadHash
# 24  911C3D0147944E0525486B5038CBBB1A  16AC61434241FE02A2B284BAF0942176
# 25                           RunHash                          ReadHash
# 26  2B4DF9A1081939194E4F6277CC80C701  451FB877FE38DA4493657D329BC6028A
# 27                           RunHash                          ReadHash
# 28  28A381FE21EFAF975AAA02463E97330D  8E2C6D7AA6E38D8913D23A01021E7F79
# 29                           RunHash                          ReadHash
# 30  87FAED6F86364DE24CC11FFE11C861D1  474F12684A5A4732CA7577077CAE29C3
# 31                           RunHash                          ReadHash
# 32  6793F41CAC2BEA6932EDF1993F2592E3  A38D572BE3C951F7E3FAC5AB32CF1934
# 33                           RunHash                          ReadHash
# 34  401E1FBF6A7FC7303D1579A077709E02  85680DC406A3BE982513259A484114CA
# 35                           RunHash                          ReadHash
# 36  1E287BE13D595329A28ED4F0412C7110  A6663EC50D977188A29C1437BEB451D9
# 37                           RunHash                          ReadHash
# 38  3BA1AC988B26AD909BCB2A2FADC64AE8  48CAE2C7F308191FF40219E885B19A13
# 39                           RunHash                          ReadHash
# 40  C798E15DE51B4136A08C43B1870D8D9D  327DB8EBAD2D61180652F238C17AF0F3
# 41                           RunHash                          ReadHash
# 42  C6F4C4BD033DB851E38A772A61BC92BD  DEFAD98397CB70D54E5412F817F10CDF
# 43                           RunHash                          ReadHash
# 44  8B1B76506E6EA5C22378B5BE7FED5982  BEA6DF7ABC6ED97354B115431FD99F39
# 45                           RunHash                          ReadHash
# 46  72CF79CAFAC40AB75E8FA1F6262FF012  98DE76E00EFAA677BE112767733039FB
# 47                           RunHash                          ReadHash
# 48  378313BE496BE622156D39B9BC249DBE  8691DCD5C7162E84498BC0924B3E88CB
# 49                           RunHash                          ReadHash
# 50  A183102C0C825743A4DD38076773B7CF  A25B5262CA1163C571F67BFA369BA8C6
# 51                           RunHash                          ReadHash
# 52  8310B6B327E106FE4E1FF46F5A5A1310  D5FB69C4E571A447F1E41E65D781B0E3
# 53                           RunHash                          ReadHash
# 54  B270EDC24AD1889A87AFEE7B3C3E0F72  13E6310A46AAA14FE016632AD47EF693
# 55                           RunHash                          ReadHash
# 56  9DB127E2AD2F9E4A6A21C436260E4472  6B4A2D69579ED2E0DBBC02030CF728C3
# 57                           RunHash                          ReadHash
# 58  CA3072AD4C601B56F9F2C584EAE788F0  F69CE56FAC7F04EAF6E4C3779430C0FC
#
# [59 rows x 47 columns]

# %% [markdown]
# ##You can also read the .txt file in Excel, remove the duplicated rows, and save it as .csv file
